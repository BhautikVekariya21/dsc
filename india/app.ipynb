# %%
import pandas as pd

cencus = pd.read_csv(r'C:\Users\bhaut\OneDrive\Desktop\dsc\india\india_census_housing-hlpca-full.csv')
cencus.head()
langlant = pd.read_csv(r'C:\Users\bhaut\OneDrive\Desktop\dsc\india\district wise centroids.csv')
langlant.head()
final_df = langlant.merge(cencus, left_on='District',right_on='District Name').drop(columns=['District Name','State Name'])
final_df.to_csv('final.csv', index=False)

# %%
pop =pd.read_csv(r'C:\Users\bhaut\OneDrive\Desktop\dsc\india\india.csv')

# %%
final_csv = final_df.merge(pop, left_on='District',right_on='District')
final_csv = final_csv.drop_duplicates()
final_csv.to_csv('final_csv.csv', index=False)
final_csv.rename(columns={'Latitude_x': 'Latitude', 'Longitude_x': 'Longitude'}, inplace=True)
final_csv = dta_cleaned = final_csv.drop(final_csv.columns[1], axis=1)
# Out:
#              State_x        District   Latitude  Longitude  State Code  \
# 0     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 1     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 2     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 3     Andhra Pradesh       Anantapur  14.312066  77.460158          28
# 4     Andhra Pradesh       Anantapur  14.312066  77.460158          28
# ...              ...             ...        ...        ...         ...
# 1702     West Bengal        Puruliya  23.254192  86.396853          19
# 1703     West Bengal        Puruliya  23.254192  86.396853          19
# 1704     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
# 1705     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
# 1706     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
#
#       District Code  Tehsil Code     Tehsil Name  Town Code/Village code  \
# ...

# %%
dta_cleaned = final_csv.loc[:, final_csv.columns != 'District code']

# Display the first few rows of the cleaned DataFrame
dta_cleaned.head()
# Out:
#           State_x   District   Latitude  Longitude  State Code  District Code  \
# 0  Andhra Pradesh   Adilabad  19.284514  78.813212          28            532
# 1  Andhra Pradesh   Adilabad  19.284514  78.813212          28            532
# 2  Andhra Pradesh   Adilabad  19.284514  78.813212          28            532
# 3  Andhra Pradesh  Anantapur  14.312066  77.460158          28            553
# 4  Andhra Pradesh  Anantapur  14.312066  77.460158          28            553
#
#    Tehsil Code Tehsil Name  Town Code/Village code  Ward No  ...  \
# 0            0    Adilabad                       0        0  ...
# 1            0    Adilabad                       0        0  ...
# 2            0    Adilabad                       0        0  ...
# 3            0   Anantapur                       0        0  ...
# 4            0   Anantapur                       0        0  ...
#
#   Contition_R_Total Residence_Good  Residence_Livable  Residence_Dilapidated  \
# ...

# %%
final_csv.rename(columns={'State_x': 'State'}, inplace=True)
final_csv
# Out:
#                State        District   Latitude  Longitude  State Code  \
# 0     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 1     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 2     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 3     Andhra Pradesh       Anantapur  14.312066  77.460158          28
# 4     Andhra Pradesh       Anantapur  14.312066  77.460158          28
# ...              ...             ...        ...        ...         ...
# 1702     West Bengal        Puruliya  23.254192  86.396853          19
# 1703     West Bengal        Puruliya  23.254192  86.396853          19
# 1704     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
# 1705     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
# 1706     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
#
#       District Code  Tehsil Code     Tehsil Name  Town Code/Village code  \
# ...

# %%
dta_cleaned = final_csv.loc[:, final_csv.columns != 'District code']

# Display the first few rows of the cleaned DataFrame
dta = dta_cleaned.to_csv('cleaned_data.csv', index=False)

# %%
dta_cleaned
# Out:
#                State        District   Latitude  Longitude  State Code  \
# 0     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 1     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 2     Andhra Pradesh        Adilabad  19.284514  78.813212          28
# 3     Andhra Pradesh       Anantapur  14.312066  77.460158          28
# 4     Andhra Pradesh       Anantapur  14.312066  77.460158          28
# ...              ...             ...        ...        ...         ...
# 1702     West Bengal        Puruliya  23.254192  86.396853          19
# 1703     West Bengal        Puruliya  23.254192  86.396853          19
# 1704     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
# 1705     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
# 1706     West Bengal  Uttar Dinajpur  26.044619  88.235952          19
#
#       District Code  Tehsil Code     Tehsil Name  Town Code/Village code  \
# ...
