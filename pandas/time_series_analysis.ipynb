# %% [markdown]
# ## timedelta object
# ### represents a duration,the difference two dates or times

# %%
# create using timestamp objects
import pandas as pd
t1 = pd.Timestamp('2017-01-01')
t2 = pd.Timestamp('2017-01-02')
t2-t1
# Out:
# Timedelta('1 days 00:00:00')

# %%
# standalone creation
pd.Timedelta(days=2,hours=10,minutes=35)
# Out:
# Timedelta('2 days 10:35:00')

# %%
#arithmatic
pd.Timestamp('6th jan 2023') + pd.Timedelta('2 days 3 hours')
# Out:
# Timestamp('2023-01-08 03:00:00')

# %%
pd.date_range(start='2020-01-01', end='2020-01-10', freq='D') + pd.Timedelta(days=2,hours=10,minutes=27)
# Out:
# DatetimeIndex(['2020-01-03 10:27:00', '2020-01-04 10:27:00',
#                '2020-01-05 10:27:00', '2020-01-06 10:27:00',
#                '2020-01-07 10:27:00', '2020-01-08 10:27:00',
#                '2020-01-09 10:27:00', '2020-01-10 10:27:00',
#                '2020-01-11 10:27:00', '2020-01-12 10:27:00'],
#               dtype='datetime64[ns]', freq='D')

# %%
# real life example
df = pd.read_csv('amazon_delivery.csv')
df.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43739 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43739 non-null  object
#  1   Agent_Age        43739 non-null  int64
#  2   Agent_Rating     43685 non-null  float64
#  3   Store_Latitude   43739 non-null  float64
#  4   Store_Longitude  43739 non-null  float64
#  5   Drop_Latitude    43739 non-null  float64
#  6   Drop_Longitude   43739 non-null  float64
#  7   Order_Date       43739 non-null  object
#  8   Order_Time       43739 non-null  object
#  9   Pickup_Time      43739 non-null  object
#  10  Weather          43648 non-null  object
#  11  Traffic          43739 non-null  object
#  12  Vehicle          43739 non-null  object
#  13  Area             43739 non-null  object
#  14  Delivery_Time    43739 non-null  int64
#  15  Category         43739 non-null  object
# ...

# %%
df.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43739 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43739 non-null  object
#  1   Agent_Age        43739 non-null  int64
#  2   Agent_Rating     43685 non-null  float64
#  3   Store_Latitude   43739 non-null  float64
#  4   Store_Longitude  43739 non-null  float64
#  5   Drop_Latitude    43739 non-null  float64
#  6   Drop_Longitude   43739 non-null  float64
#  7   Order_Date       43739 non-null  datetime64[ns]
#  8   Order_Time       43739 non-null  object
#  9   Pickup_Time      43739 non-null  object
#  10  Weather          43648 non-null  object
#  11  Traffic          43739 non-null  object
#  12  Vehicle          43739 non-null  object
#  13  Area             43739 non-null  object
#  14  Delivery_Time    43739 non-null  int64
#  15  Category         43739 non-null  object
# ...

# %%
df['Order_Time'] = pd.to_datetime(df['Order_Time'],errors='coerce')
# Out:
# C:\Users\bhaut\AppData\Local\Temp\ipykernel_7316\3590184363.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order_Time'] = pd.to_datetime(df['Order_Time'],errors='coerce')

# %%
df['Pickup_Time'] = pd.to_datetime(df['Pickup_Time'])
# Out:
# C:\Users\bhaut\AppData\Local\Temp\ipykernel_7316\129968673.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Pickup_Time'] = pd.to_datetime(df['Pickup_Time'])

# %%
df['Pickup_Delay'] = df['Pickup_Time'] - df['Order_Time']
df['Pickup_Delay'].mean()
# Out:
# Timedelta('-1 days +23:42:40.474706745')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43739 entries, 0 to 43738
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43739 non-null  object
#  1   Agent_Age        43739 non-null  int64
#  2   Agent_Rating     43685 non-null  float64
#  3   Store_Latitude   43739 non-null  float64
#  4   Store_Longitude  43739 non-null  float64
#  5   Drop_Latitude    43739 non-null  float64
#  6   Drop_Longitude   43739 non-null  float64
#  7   Order_Date       43739 non-null  datetime64[ns]
#  8   Order_Time       43648 non-null  datetime64[ns]
#  9   Pickup_Time      43739 non-null  datetime64[ns]
#  10  Weather          43648 non-null  object
#  11  Traffic          43739 non-null  object
#  12  Vehicle          43739 non-null  object
#  13  Area             43739 non-null  object
#  14  Delivery_Time    43739 non-null  int64
#  15  Category         43739 non-null  object
# ...

# %% [markdown]
# ## time series
# #### a time series is a data set that tracks a sample over time.in particular,a time series allows one to see what factors influence certain variables from period to period. time series analysis can be useful can be useful to see how w given asset,security,or economic variable changes over time.
# - finnancial data (company stocks)
# - natural data (rainfall measurment)
# - event data (covid)
# - medical data (heart rate monitoring)
# #### types of operation done on time series
# - time series analysis
# - time series forecasting

# %%
tesla = pd.read_csv('TSLA.csv')
tesla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 1     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# 3     2010-07-07    3.280000    3.326000    2.996000    3.160000    3.160000
# 4     2010-07-08    3.228000    3.504000    3.114000    3.492000    3.492000
# ...          ...         ...         ...         ...         ...         ...
# 2838  2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2839  2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2840  2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2841  2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2842  2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#         Volume
# 0     41094000
# ...

# %%
tesla.tail(10)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2833  2021-10-01  778.400024  780.780029  763.590027  775.219971  775.219971
# 2834  2021-10-04  796.500000  806.969971  776.119995  781.530029  781.530029
# 2835  2021-10-05  784.799988  797.309998  774.200012  780.590027  780.590027
# 2836  2021-10-06  776.200012  786.659973  773.219971  782.750000  782.750000
# 2837  2021-10-07  785.460022  805.000000  783.380005  793.609985  793.609985
# 2838  2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2839  2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2840  2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2841  2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2842  2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#         Volume
# 2833  17031400
# 2834  30483300
# 2835  18432600
# 2836  14632800
# 2837  19195800
# 2838  16711100
# ...

# %%
veg = pd.read_csv('vegetables.csv')
veg
# Out:
#             SN            Commodity        Date Unit  Minimum  Maximum  \
# 0            0   Tomato Big(Nepali)  2013-06-16   Kg     35.0     40.0
# 1            1  Tomato Small(Local)  2013-06-16   Kg     26.0     32.0
# 2            2           Potato Red  2013-06-16   Kg     20.0     21.0
# 3            3         Potato White  2013-06-16   Kg     15.0     16.0
# 4            4   Onion Dry (Indian)  2013-06-16   Kg     28.0     30.0
# ...        ...                  ...         ...  ...      ...      ...
# 197156  197156    Garlic Dry Nepali  2021-05-13   Kg    100.0    120.0
# 197157  197157     Fish Fresh(Rahu)  2021-05-13   KG    270.0    280.0
# 197158  197158  Fish Fresh(Bachuwa)  2021-05-13   KG    225.0    235.0
# 197159  197159   Fish Fresh(Chhadi)  2021-05-13   KG    220.0    230.0
# 197160  197160  Fish Fresh(Mungari)  2021-05-13   KG    240.0    250.0
#
#         Average
# 0          37.5
# 1          29.0
# 2          20.5
# 3          15.5
# 4          29.0
# ...

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2843 entries, 0 to 2842
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2843 non-null   object
#  1   Open       2843 non-null   float64
#  2   High       2843 non-null   float64
#  3   Low        2843 non-null   float64
#  4   Close      2843 non-null   float64
#  5   Adj Close  2843 non-null   float64
#  6   Volume     2843 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 155.6+ KB

# %%
veg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197161 entries, 0 to 197160
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   SN         197161 non-null  int64
#  1   Commodity  197161 non-null  object
#  2   Date       197161 non-null  object
#  3   Unit       197161 non-null  object
#  4   Minimum    197161 non-null  float64
#  5   Maximum    197161 non-null  float64
#  6   Average    197161 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 10.5+ MB

# %%
tesla['Date'] = pd.to_datetime(tesla['Date'])
veg['Date'] = pd.to_datetime(veg['Date'])

# %%
veg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197161 entries, 0 to 197160
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   SN         197161 non-null  int64
#  1   Commodity  197161 non-null  object
#  2   Date       197161 non-null  datetime64[ns]
#  3   Unit       197161 non-null  object
#  4   Minimum    197161 non-null  float64
#  5   Maximum    197161 non-null  float64
#  6   Average    197161 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 10.5+ MB

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2843 entries, 0 to 2842
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2843 non-null   datetime64[ns]
#  1   Open       2843 non-null   float64
#  2   High       2843 non-null   float64
#  3   Low        2843 non-null   float64
#  4   Close      2843 non-null   float64
#  5   Adj Close  2843 non-null   float64
#  6   Volume     2843 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 155.6 KB

# %%
tesla.set_index('Date', inplace=True)
tesla.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# 2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500
# 2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000

# %%
veg.set_index('Date', inplace=True)
veg.head()
# Out:
#             SN            Commodity Unit  Minimum  Maximum  Average
# Date
# 2013-06-16   0   Tomato Big(Nepali)   Kg     35.0     40.0     37.5
# 2013-06-16   1  Tomato Small(Local)   Kg     26.0     32.0     29.0
# 2013-06-16   2           Potato Red   Kg     20.0     21.0     20.5
# 2013-06-16   3         Potato White   Kg     15.0     16.0     15.5
# 2013-06-16   4   Onion Dry (Indian)   Kg     28.0     30.0     29.0

# %%
tesla.loc['2020-01-01':'2020-01-10']
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  84.900002  86.139999  84.342003  86.052002  86.052002   47660500
# 2020-01-03  88.099998  90.800003  87.384003  88.601997  88.601997   88892500
# 2020-01-06  88.094002  90.311996  88.000000  90.307999  90.307999   50665000
# 2020-01-07  92.279999  94.325996  90.671997  93.811996  93.811996   89410500
# 2020-01-08  94.739998  99.697998  93.646004  98.428001  98.428001  155721500
# 2020-01-09  99.419998  99.760002  94.573997  96.267998  96.267998  142202000
# 2020-01-10  96.358002  96.987999  94.739998  95.629997  95.629997   64797500

# %%
#fetching a single date
tesla.loc['2021-01-21']
# Out:
# Open         8.550000e+02
# High         8.557200e+02
# Low          8.414200e+02
# Close        8.449900e+02
# Adj Close    8.449900e+02
# Volume       2.052110e+07
# Name: 2021-01-21 00:00:00, dtype: float64

# %%
#partial date indexing -> selecting a month/year
tesla.loc['2021-01']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  719.460022  744.489990  717.190002  729.770020  729.770020
# 2021-01-05  723.659973  740.840027  719.200012  735.109985  735.109985
# 2021-01-06  758.489990  774.000000  749.099976  755.979980  755.979980
# 2021-01-07  777.630005  816.989990  775.200012  816.039978  816.039978
# 2021-01-08  856.000000  884.489990  838.390015  880.020020  880.020020
# 2021-01-11  849.400024  854.429993  803.619995  811.190002  811.190002
# 2021-01-12  831.000000  868.000000  827.340027  849.440002  849.440002
# 2021-01-13  852.760010  860.469971  832.000000  854.409973  854.409973
# 2021-01-14  843.390015  863.000000  838.750000  845.000000  845.000000
# 2021-01-15  852.000000  859.900024  819.099976  826.159973  826.159973
# 2021-01-19  837.799988  850.000000  833.000000  844.549988  844.549988
# 2021-01-20  858.739990  859.500000  837.280029  850.450012  850.450012
# ...

# %%
tesla.loc['2021']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  719.460022  744.489990  717.190002  729.770020  729.770020
# 2021-01-05  723.659973  740.840027  719.200012  735.109985  735.109985
# 2021-01-06  758.489990  774.000000  749.099976  755.979980  755.979980
# 2021-01-07  777.630005  816.989990  775.200012  816.039978  816.039978
# 2021-01-08  856.000000  884.489990  838.390015  880.020020  880.020020
# ...                ...         ...         ...         ...         ...
# 2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#               Volume
# Date
# 2021-01-04  48638200
# 2021-01-05  32245200
# 2021-01-06  44700000
# ...

# %%
# create a year month and day name column
tesla['Year'] = tesla.index.year
tesla['Month'] = tesla.index.month_name()
tesla['Day'] = tesla.index.day_name()
tesla['quarter'] = tesla.index.quarter

# %%
tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# 2010-07-07    3.280000    3.326000    2.996000    3.160000    3.160000
# 2010-07-08    3.228000    3.504000    3.114000    3.492000    3.492000
# ...                ...         ...         ...         ...         ...
# 2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#               Volume  Year    Month        Day  quarter  Low_shifted  \
# Date
# ...

# %%
#slicing the data
tesla.loc['2020-01-01':'2020-01-10', ['Open', 'Close']]
# Out:
#                  Open      Close
# Date
# 2020-01-02  84.900002  86.052002
# 2020-01-03  88.099998  88.601997
# 2020-01-06  88.094002  90.307999
# 2020-01-07  92.279999  93.811996
# 2020-01-08  94.739998  98.428001
# 2020-01-09  99.419998  96.267998
# 2020-01-10  96.358002  95.629997

# %%
# challenege -> fetch info for a particular date every year -> limitaion of timedelta
tesla[tesla.index.isin(pd.date_range(start='2011-02-11', end='2022-02-11', freq=pd.DateOffset(years=1)))]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-02-11    4.650000    4.750000    4.588000    4.650000    4.650000
# 2013-02-11    7.596000    7.830000    7.500000    7.684000    7.684000
# 2014-02-11   39.793999   40.439999   38.540001   39.324001   39.324001
# 2015-02-11   42.442001   42.948002   41.456001   42.560001   42.560001
# 2016-02-11   30.400000   32.652000   29.400000   30.094000   30.094000
# 2019-02-11   62.320000   63.720001   62.099998   62.568001   62.568001
# 2020-02-11  153.757996  156.701996  151.600006  154.876007  154.876007
# 2021-02-11  812.440002  829.880005  801.729980  811.659973  811.659973
#
#               Volume  Year     Month        Day  quarter
# Date
# 2011-02-11   3172500  2011  February     Friday        1
# 2013-02-11  16331500  2013  February     Monday        1
# 2014-02-11  53549500  2014  February    Tuesday        1
# 2015-02-11  48845500  2015  February  Wednesday        1
# ...

# %%
# viz a single column
tesla['Open'].plot(title='Tesla Open Price', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Tesla Open Price'}, xlabel='Date'>

# %%
# create a year month and day name column
veg['Year'] = veg.index.year
veg['Month'] = veg.index.month_name()
veg['Day'] = veg.index.day_name()
veg['quarter'] = veg.index.quarter
veg
# Out:
#                 SN            Commodity Unit  Minimum  Maximum  Average  Year  \
# Date
# 2013-06-16       0   Tomato Big(Nepali)   Kg     35.0     40.0     37.5  2013
# 2013-06-16       1  Tomato Small(Local)   Kg     26.0     32.0     29.0  2013
# 2013-06-16       2           Potato Red   Kg     20.0     21.0     20.5  2013
# 2013-06-16       3         Potato White   Kg     15.0     16.0     15.5  2013
# 2013-06-16       4   Onion Dry (Indian)   Kg     28.0     30.0     29.0  2013
# ...            ...                  ...  ...      ...      ...      ...   ...
# 2021-05-13  197156    Garlic Dry Nepali   Kg    100.0    120.0    110.0  2021
# 2021-05-13  197157     Fish Fresh(Rahu)   KG    270.0    280.0    275.0  2021
# 2021-05-13  197158  Fish Fresh(Bachuwa)   KG    225.0    235.0    230.0  2021
# 2021-05-13  197159   Fish Fresh(Chhadi)   KG    220.0    230.0    225.0  2021
# 2021-05-13  197160  Fish Fresh(Mungari)   KG    240.0    250.0    245.0  2021
#
# ...

# %%
# viz all coumn together
subsets = tesla[['High', 'Low', 'Close', 'Volume']]
ax = subsets.plot(subplots=True,
                sharey=False,
                layout=(2,2),
                linewidth=1,
                figsize=(20, 15),
                fontsize=10,   
                legend=True,
                grid=True,
                title=['High', 'Low', 'Close', 'Volume']
)

# %%
#plot for a particular year/month/week
tesla.loc['2020']['High'].plot(title='Tesla Stock Prices in 2020', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices in 2020'}, xlabel='Date'>

# %%
#montly trend
tesla['High'].asfreq('ME').plot(title='Tesla Stock Prices Monthly Trend', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices Monthly Trend'}, xlabel='Date'>

# %%
#yearly trend
tesla['High'].asfreq('YE').plot(title='Tesla Stock Prices Yearly Trend', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices Yearly Trend'}, xlabel='Date'>

# %%
#quarterly trend
tesla['High'].asfreq('QE').plot(title='Tesla Stock Prices Quarterly Trend', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices Quarterly Trend'}, xlabel='Date'>

# %%
tesla.groupby('Day')['High'].mean().plot(title='Tesla Stock Prices by Day of the Week', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices by Day of the Week'}, xlabel='Day'>

# %%
tesla.groupby('Month')['High'].mean().plot(title='Tesla Stock Prices by Month', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices by Month'}, xlabel='Month'>

# %%
tesla.groupby('Year')['High'].mean().plot(title='Tesla Stock Prices Yearly Average', figsize=(12, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices Yearly Average'}, xlabel='Year'>

# %% [markdown]
# # Resampling
# ### resampling involves changing the frequency of your time series observations.
# ### two types of resampling are:
# ### `upsampling`: where you increase the frequency of the smaples,such as from minutes to seconds.
# ### `downsampling`: where you decrease the frequency of the samples,such as from days to months.

# %%
# downsampling
tesla['High'].plot(title='Tesla Stock Prices', figsize=(10, 6))
tesla['High'].resample('W').mean().plot(title='Tesla Stock Prices Monthly Average', figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices Monthly Average'}, xlabel='Date'>

# %%
#downsampling with different frequency
tesla['High'].plot(title='Tesla Stock Prices', figsize=(10, 6))
tesla['High'].resample('ME').mean().plot(title='Tesla Stock Prices Monthly Average', figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices Monthly Average'}, xlabel='Date'>

# %%
#downsampling with different frequency
tesla['High'].plot(title='Tesla Stock Prices', figsize=(10, 6))
tesla['High'].resample('YE').mean().plot(title='Tesla Stock Prices Monthly Average', figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices Monthly Average'}, xlabel='Date'>

# %%
#Upsampling
tesla['High'].plot(title='Tesla Stock Prices', figsize=(10, 6))
tesla['High'].resample('h').interpolate(method='linear').plot(title='Tesla Stock Prices Daily Average', figsize=(10, 6))
tesla['High'].resample('3min').interpolate(method='spline',order=2).plot(title='Tesla Stock Prices Daily Average', figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices Daily Average'}, xlabel='Date'>

# %% [markdown]
# # Rolling window(smoothing)
# ### time series data in original format can be quite volatile,especially on smaller aggregation levels.the concept of rolling,or moving averages is a useful technique for smoothning time series data

# %%
# rolling window
tesla['High'].plot(title='Tesla Stock Prices', figsize=(10, 6))
tesla['High'].rolling(window=7).mean().plot(title='Tesla Stock Prices 7 Day Rolling Average', figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices 7 Day Rolling Average'}, xlabel='Date'>

# %%
tesla['High'].rolling(window=4).mean()
# Out:
# Date
# 2010-07-01           NaN
# 2010-07-02           NaN
# 2010-07-06           NaN
# 2010-07-07      4.282500
# 2010-07-08      3.862500
#                  ...
# 2021-10-08    796.337494
# 2021-10-11    797.319992
# 2021-10-12    803.735001
# 2021-10-13    806.337494
# 2021-10-14    812.304993
# Name: High, Length: 2843, dtype: float64

# %%
tesla['High'].plot(title='Tesla Stock Prices', figsize=(10, 6))
tesla['High'].rolling(window=120).mean().plot(title='Tesla Stock Prices 30 Day Rolling Average', figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Tesla Stock Prices 30 Day Rolling Average'}, xlabel='Date'>

# %%
tesla['High'].plot(title='Tesla Stock Prices', figsize=(12, 6),legend=True)
tesla['High'].rolling(window=30).mean().plot(title='Tesla Stock Prices 30 Day Rolling Average', figsize=(12, 6),legend=True)    
tesla['High'].ewm(span=30).mean().plot(title='Tesla Stock Prices 30 Day Exponential Moving Average', figsize=(12, 6),legend=True)
# Out:
# <Axes: title={'center': 'Tesla Stock Prices 30 Day Exponential Moving Average'}, xlabel='Date'>

# %% [markdown]
# # shifting
# ### the shift() function in pandas is used to,well shift the series up or down by the desired number of periods.

# %%
tesla['Adj Close'].shift(2)
# Out:
# Date
# 2010-07-01           NaN
# 2010-07-02           NaN
# 2010-07-06      4.392000
# 2010-07-07      3.840000
# 2010-07-08      3.222000
#                  ...
# 2021-10-08    782.750000
# 2021-10-11    793.609985
# 2021-10-12    785.489990
# 2021-10-13    791.940002
# 2021-10-14    805.719971
# Name: Adj Close, Length: 2843, dtype: float64

# %%
tesla['Adj Close'].shift(-2).tail(10)
# Out:
# Date
# 2021-10-01    780.590027
# 2021-10-04    782.750000
# 2021-10-05    793.609985
# 2021-10-06    785.489990
# 2021-10-07    791.940002
# 2021-10-08    805.719971
# 2021-10-11    811.080017
# 2021-10-12    818.320007
# 2021-10-13           NaN
# 2021-10-14           NaN
# Name: Adj Close, dtype: float64

# %%
import pandas as pd

# Shift the 'Low' and 'High' columns by 1
tesla['Low_shifted'] = tesla['Low'].shift(1)
tesla['High_shifted'] = tesla['High'].shift(1)

# Create subplots using pandas plotting (via `.plot()` with `subplots=True`)
tesla[['Open', 'Close', 'Low_shifted', 'High_shifted']].plot(subplots=True, layout=(2, 2), figsize=(10, 6), title='Tesla Stock Metrics (with Shifted Low & High)')
# Out:
# array([[<Axes: xlabel='Date'>, <Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>, <Axes: xlabel='Date'>]], dtype=object)
