# %% [markdown]
# ## `Q-1:` Rectangle Class
# 1. Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.
#
# 2. Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of ​​the rectangle.
#
# 3. Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class.

# %% [markdown]
# Eg.
# After making above classes and methods, on executing below code:-
# ```
# my_rectangle = Rectangle(3 , 4)
# my_rectangle.display()
# ```
#
# `Output:`
# ```
# The length of rectangle is:  3
# The width of rectangle is:  4
# The perimeter of rectangle is:  14
# The area of rectangle is:  12
# ```

# %%
class Rectangle:
    def __init__(self, length, width):
        # Private attributes
        self.__length = length
        self.__width = width
    
    def __perimeter(self):
        # Private method to calculate perimeter
        return 2 * (self.__length + self.__width)
    
    def __area(self):
        # Private method to calculate area
        return self.__length * self.__width
    
    def display(self):
        # Display the length, width, perimeter, and area
        print(f"The length of rectangle is: {self.__length}")
        print(f"The width of rectangle is: {self.__width}")
        print(f"The perimeter of rectangle is: {self.__perimeter()}")
        print(f"The area of rectangle is: {self.__area()}")

# Create an instance of Rectangle class
my_rectangle = Rectangle(3, 4)

# Call the display method to show the rectangle's properties
my_rectangle.display()

# Uncommenting the following lines would raise an AttributeError because of private access
# print(my_rectangle.__length)  # Will raise an error
# print(my_rectangle.__width)  # Will raise an error
# Out:
# The length of rectangle is: 3
# The width of rectangle is: 4
# The perimeter of rectangle is: 14
# The area of rectangle is: 12

# %% [markdown]
# ## `Q-2: Bank Class`
#
# 1. Create a Python class called `BankAccount` which represents a bank account, having as attributes: `accountNumber` (numeric type), `name` (name of the account owner as string type), `balance`.
# 2. Create a constructor with parameters: `accountNumber, name, balance`.
# 3. Create a `Deposit()` method which manages the deposit actions.
# 4. Create a `Withdrawal()` method  which manages withdrawals actions.
# 5. Create an `bankFees()` method to apply the bank fees with a percentage of 5% of the balance account.
# 6. Create a `display()` method to display account details.
# Give the complete code for the  BankAccount class.

# %% [markdown]
# Eg.
# After making above classes and methods, on executing below code:-
# ```
# newAccount = BankAccount(2178514584, "Mandy" , 2800)
#
# newAccount.Withdrawal(700)
#
# newAccount.Deposit(1000)
#
# newAccount.display()
# ```
#
# `Output:`
# ```
# Account Number :  2178514584
# Account Name :  Mandy
# Account Balance :  3100 ₹
# ```

# %%
class BankAccount:
    def __init__(self, accountNumber, name, balance):
        # Initialize the account details
        self.accountNumber = accountNumber
        self.name = name
        self.balance = balance

    def Deposit(self, amount):
        # Method to deposit money into the account
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} ₹. New balance: {self.balance} ₹")
        else:
            print("Deposit amount must be positive!")

    def Withdrawal(self, amount):
        # Method to withdraw money from the account
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount} ₹. New balance: {self.balance} ₹")
        else:
            print("Insufficient funds or invalid withdrawal amount!")

    def bankFees(self):
        # Method to apply bank fees (5% of the current balance)
        fees = 0.05 * self.balance
        self.balance -= fees
        print(f"Bank fees applied: {fees} ₹. New balance: {self.balance} ₹")

    def display(self):
        # Method to display account details
        print(f"Account Number : {self.accountNumber}")
        print(f"Account Name : {self.name}")
        print(f"Account Balance : {self.balance} ₹")


# Creating a new BankAccount instance
newAccount = BankAccount(2178514584, "Mandy", 2800)

# Perform some actions
newAccount.Withdrawal(700)  # Withdraw 700 ₹
newAccount.Deposit(1000)     # Deposit 1000 ₹
newAccount.bankFees()        # Apply bank fees
newAccount.display()         # Display account details
# Out:
# Withdrew 700 ₹. New balance: 2100 ₹
# Deposited 1000 ₹. New balance: 3100 ₹
# Bank fees applied: 155.0 ₹. New balance: 2945.0 ₹
# Account Number : 2178514584
# Account Name : Mandy
# Account Balance : 2945.0 ₹

# %% [markdown]
# ## `Q-3:Computation class`
#
# 1. Create a `Computation` class with a default constructor (without parameters) allowing to perform various calculations on integers numbers.
# 2. Create a method called `Factorial()` which allows to calculate the factorial of an integer n. Integer n as parameter for this method
#
# 3. Create a method called `naturalSum()` allowing to calculate the sum of the first n integers 1 + 2 + 3 + .. + n. Integer n as parameter for this method.
#
# 4. Create a method called `testPrime()` in  the Calculation class to test the primality of a given integer n, n is Prime or Not? Integer n as parameter for this method.
#
# 5. Create  a method called `testPrims()` allowing to test if two numbers are prime between them. Two integers are prime to one another if they have only `1` as their common divisor. Eg. 4 and 9 are prime to each other.
#
# 5. Create a `tableMult()` method which creates and displays the multiplication table of a given integer. Then create an `allTablesMult()` method to display all the integer multiplication tables 1, 2, 3, ..., 9.
#
# 6. Create a static `listDiv()` method that gets all the divisors of a given integer on new list called  Ldiv. Create another `listDivPrim()` method that gets all the prime divisors of a given integer.

# %%
class Computation:
    def __init__(self):
        # Default constructor with no parameters
        pass

    def Factorial(self, n):
        # Method to calculate the factorial of a number
        if n == 0 or n == 1:
            return 1
        else:
            fact = 1
            for i in range(1, n + 1):
                fact *= i
            return fact

    def naturalSum(self, n):
        # Method to calculate the sum of the first n natural numbers
        return n * (n + 1) // 2  # Sum formula: n * (n + 1) / 2

    @staticmethod
    def testPrime(n):
        # Method to test if a number is prime
        if n <= 1:
            return False
        for i in range(2, int(n ** 0.5) + 1):
            if n % i == 0:
                return False
        return True

    def testPrims(self, a, b):
        # Method to test if two numbers are prime to each other (i.e., gcd(a, b) == 1)
        def gcd(x, y):
            while y:
                x, y = y, x % y
            return x

        if gcd(a, b) == 1:
            return True
        else:
            return False

    def tableMult(self, n):
        # Method to create and display the multiplication table of a given integer
        print(f"Multiplication table for {n}:")
        for i in range(1, 11):
            print(f"{n} x {i} = {n * i}")

    def allTablesMult(self):
        # Method to display all multiplication tables (1 to 9)
        for i in range(1, 10):
            self.tableMult(i)
            print("-" * 20)

    @staticmethod
    def listDiv(n):
        # Static method to get all divisors of a given integer
        divisors = []
        for i in range(1, n + 1):
            if n % i == 0:
                divisors.append(i)
        return divisors

    @staticmethod
    def listDivPrim(n):
        # Static method to get all prime divisors of a given integer
        divisors = Computation.listDiv(n)  # Get all divisors first
        prime_divisors = []
        for divisor in divisors:
            if Computation.testPrime(divisor):
                prime_divisors.append(divisor)
        return prime_divisors


# Testing the Computation class
computation = Computation()

# Factorial example
n = 5
print(f"Factorial of {n}: {computation.Factorial(n)}")

# Natural sum example
n = 10
print(f"Sum of first {n} natural numbers: {computation.naturalSum(n)}")

# Prime test example
n = 7
print(f"Is {n} prime? {computation.testPrime(n)}")

# Prime to each other test example
a, b = 4, 9
print(f"Are {a} and {b} prime to each other? {computation.testPrims(a, b)}")

# Multiplication table example
n = 3
computation.tableMult(n)

# All multiplication tables
computation.allTablesMult()

# Divisors and prime divisors example
num = 28
print(f"Divisors of {num}: {computation.listDiv(num)}")
print(f"Prime divisors of {num}: {computation.listDivPrim(num)}")
# Out:
# Factorial of 5: 120
# Sum of first 10 natural numbers: 55
# Is 7 prime? True
# Are 4 and 9 prime to each other? True
# Multiplication table for 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# Multiplication table for 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# --------------------
# Multiplication table for 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# --------------------
# Multiplication table for 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# --------------------
# Multiplication table for 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# --------------------
# ...

# %% [markdown]
# ## `Q-4`: Build flashcard using class in Python.
#
# Build a flashcard using class in python. A flashcard is a card having information on both sides, which can be used as an aid in memoization. Flashcards usually have a question on one side and an answer on the other.
#
# **Example 1:**
#
# Approach:
#
# - Create a class named FlashCard.
# - Initialize dictionary fruits using __init__() method. Here you have to define fruit name as key and it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
# - Now randomly choose a pair from fruits by using _random_ module and store the key in variable _fruit_ and _value_ in variable color.
# - Now prompt the user to answer the color of the randomly chosen fruit.
# - If correct print correct else print wrong.
#
# Output:
# ```bash
# welcome to fruit quiz
# What is the color of Strawberries
# pink
# Correct answer
# Enter 0, if you want to play again: 0
# What is the color of watermelon
# green
# Correct answer
# Enter 0, if you want to play again: 1
# ```

# %%
import random

class FlashCard:
    def __init__(self):
        # Initializing the dictionary with fruit names and their corresponding colors
        self.fruits = {
            "Banana": "yellow",
            "Strawberries": "pink",
            "Watermelon": "green",
            "Apple": "red",
            "Grapes": "purple",
            "Orange": "orange",
            "Lemon": "yellow",
            "Blueberry": "blue"
        }

    def play(self):
        print("Welcome to the Fruit Quiz!")

        while True:
            # Randomly choosing a fruit from the dictionary
            fruit, color = random.choice(list(self.fruits.items()))

            # Prompting the user for the color of the fruit
            answer = input(f"What is the color of {fruit}? ")
                                    
            # Checking if the answer is correct
            if answer.lower() == color.lower():
                print("Correct answer!")
            else:
                print(f"Wrong answer! The correct color is {color}.")

            # Asking the user if they want to play again
            play_again = input("Enter 0 if you want to play again or any other key to exit: ")
            if play_again != "0":
                print("Thanks for playing!")
                break

# Create an instance of the FlashCard class and start the quiz
flashcard_game = FlashCard()
flashcard_game.play()
# Out:
# Welcome to the Fruit Quiz!
# Correct answer!
# Thanks for playing!

# %% [markdown]
# ## `Q-5:` Problem 5 based on OOP Python.
#
# TechWorld, a technology training center, wants to allocate courses for instructors. An instructor is identified by name, technology skills, experience and average feedback. An instructor is allocated a course, if he/she satisfies the below two conditions:
# - eligibility criteria:
#     - if experience is more than 3 years, average feedback should be 4.5 or more
#     - if experience is 3 years or less, average feedback should be 4 or more
# - he/she should posses the technology skill for the course
#
# Identify the class name and attributes to represent instructors. Write a Python program to implement the class chosen with its attributes and methods.
#
# **Note:**
# - Consider all instance variables to be private and methods to be public.
# - An instructor may have multiple technology skills, so consider instance variable, technology_skill to be a list.
# - *check_eligibility()*: Return true if eligibility criteria is satisfied by the instructor. Else, return false
# - *allocate_course(technology)*: Return true if the course which requires the given technology can be allocated to the instructor. Else, return false.
#
# Represent a few objects of the class, initialize instance variables using setter methods, invoke
# appropriate methods and test your program.

# %%
class Instructor:
    def __init__(self, name, technology_skills, experience, average_feedback):
        # Initializing the instance variables
        self._name = name
        self._technology_skills = technology_skills  # List of skills
        self._experience = experience
        self._average_feedback = average_feedback

    def check_eligibility(self):
        # Checking the eligibility criteria
        if self._experience > 3:
            if self._average_feedback >= 4.5:
                return True
            else:
                return False
        elif self._experience <= 3:
            if self._average_feedback >= 4.0:
                return True
            else:
                return False

    def allocate_course(self, technology):
        # Allocating the course if instructor has the required technology skill
        if technology in self._technology_skills:
            return True
        else:
            return False

    # Setter methods to set instance variables (encapsulation)
    def set_name(self, name):
        self._name = name

    def set_technology_skills(self, technology_skills):
        self._technology_skills = technology_skills

    def set_experience(self, experience):
        self._experience = experience

    def set_average_feedback(self, average_feedback):
        self._average_feedback = average_feedback

    # Getter methods to get instance variables (encapsulation)
    def get_name(self):
        return self._name

    def get_technology_skills(self):
        return self._technology_skills

    def get_experience(self):
        return self._experience

    def get_average_feedback(self):
        return self._average_feedback


# Test the program with few examples

# Create Instructor objects
instructor1 = Instructor("Alice", ["Python", "Java"], 5, 4.8)
instructor2 = Instructor("Bob", ["Java", "C++"], 2, 3.9)
instructor3 = Instructor("Charlie", ["Python", "Django"], 4, 4.3)

# Check if instructors are eligible
print(f"Is {instructor1.get_name()} eligible? {instructor1.check_eligibility()}")
print(f"Is {instructor2.get_name()} eligible? {instructor2.check_eligibility()}")
print(f"Is {instructor3.get_name()} eligible? {instructor3.check_eligibility()}")

# Test if they can be allocated courses based on their technology skills
print(f"Can {instructor1.get_name()} be allocated Python course? {instructor1.allocate_course('Python')}")
print(f"Can {instructor2.get_name()} be allocated Python course? {instructor2.allocate_course('Python')}")
print(f"Can {instructor3.get_name()} be allocated Django course? {instructor3.allocate_course('Django')}")
# Out:
# Is Alice eligible? True
# Is Bob eligible? False
# Is Charlie eligible? False
# Can Alice be allocated Python course? True
# Can Bob be allocated Python course? False
# Can Charlie be allocated Django course? True
